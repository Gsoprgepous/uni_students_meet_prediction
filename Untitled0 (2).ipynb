# %%
import pandas as pd
path="/hith.csv"
df=pd.read_csv(path)
df.head(8)
# Out:
#   colleague;day;time
# 0      Ivanov;1;9:00
# 1      Petrov;1;9:30
# 2    Sidorov;1;10:00
# 3      Ivanov;2;9:00
# 4      Petrov;2;9:30
# 5    Sidorov;2;10:00
# 6      Ivanov;3;9:00
# 7    Sidorov;4;10:00
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('colleague;day;time').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['colleague;day;time']
#                 .value_counts()
# ...

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-633941a3-51a0-4369-9c33-d5b8344163dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-633941a3-51a0-4369-9c33-d5b8344163dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path='/content/drive/MyDrive/data.xlsx'

# %%
file_path='data.xlsx'
data=pd.read_excel(file_path)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['colleague;day;time']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'colleague;day;time'}, axis=1)
              .sort_values('colleague;day;time', ascending=True))
  xs = counted['colleague;day;time']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_1.sort_values('colleague;day;time', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('colleague;day;time')):
  _plot_series(series, series_name, i)
  fig.legend(title='colleague;day;time', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('colleague;day;time')
_ = plt.ylabel('count()')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel('data.xlsx')
colleague='Kolmogorov'
day='7'
time='16:00'
results=[]

for day in data['day'].unique():
  total_visits=data[(data['day']==day)& (data['time']==time)].shape[0]
  specific_visits= data[(data['colleague']==colleague)&(data['day']==day)&(data['time']==time)].shape[0]
results.append({
      'day': day,
      'total_visits': total_visits,
      'specific_visits': specific_visits
  })
results_df=pd.DataFrame(results)
print(results_df)
# Out:
#    day  total_visits  specific_visits
# 0    7             0                0

# %%
import matplotlib.pyplot as plt
import string
fig, ax = plt.subplots()
ax.axis('off')
ax.text(0.5, 0.5, "The end for now ))", color='cyan', fontsize=24, ha='center', va='center')
plt.show()
